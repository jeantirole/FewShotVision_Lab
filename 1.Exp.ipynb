# %%
from PIL import Image
import numpy as np

# %%
img_path = "/home/eric/data/trainset/labels_color/aachen_3.png"
img_ = Image.open(img_path)
# Out:
# filename /home/eric/data/trainset/labels_color/aachen_3.png

# %%
img_.size
# Out:
# (1000, 1000)

# %%
img_ = np.asarray(img_)
img_ = img_[0:800,:,:]

# %%
img_.shape
# Out:
# (800, 1000, 3)

# %%
img_a = img_.transpose(2,0,1)

# %%
img_a.shape
# Out:
# (3, 800, 1000)

# %%
img_b = img_a.copy()

# %%
img_b = img_b * 1/800

# %%
img_c = np.concatenate((img_b, img_a),axis=1)

# %%
img_c.shape
# Out:
# (3, 1600, 1000)

# %%
img_c1 = img_c.transpose(1,2,0)

# %%
img_c1.shape
# Out:
# (1600, 1000, 3)

# %%
import matplotlib.pyplot as plt 
plt.imshow(img_c1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#-----------------------------------------------------
